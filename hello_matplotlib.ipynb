# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 2, 3], [6, 7, 8])
plt.show()

# %%
xs = np.arange(-3, 3, 0.001)
ys = xs ** 3 - xs ** 2 + 6

# %%
plt.plot(xs, ys)
plt.show()
