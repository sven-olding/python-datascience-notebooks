# %%
import pandas as pd

# %%
df = pd.read_csv("./data/Temperature/GlobalLandTemperaturesByMajorCity.csv.bz2")
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
df["AverageTemperature"].mean()
# Out:
# np.float64(18.125968852854168)

# %%
df["AverageTemperature"].sum()
# Out:
# np.float64(4135892.9429999995)

# %%
df["AverageTemperature"].to_numpy()
# Out:
# array([26.704, 27.434, 28.101, ..., 25.251, 24.528,    nan],
#       shape=(239177,))

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %% [markdown]
# # Daten ändern

# %%
df["Planet"] = "World"
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude Planet
# 0  Côte D'Ivoire    5.63N     3.23W  World
# 1  Côte D'Ivoire    5.63N     3.23W  World
# 2  Côte D'Ivoire    5.63N     3.23W  World
# 3  Côte D'Ivoire    5.63N     3.23W  World
# 4  Côte D'Ivoire    5.63N     3.23W  World

# %%
# Kopie, besser .loc
#df[df["Country"] == "Germany"]["Country"] = "Deutschland"

# %%
df.loc[0, ["City", "Country"]]
# Out:
# City             Abidjan
# Country    Côte D'Ivoire
# Name: 0, dtype: object

# %%
df.loc[df["Country"] == "Germany", "Country"]
# Out:
# 24500    Germany
# 24501    Germany
# 24502    Germany
# 24503    Germany
# 24504    Germany
#           ...
# 27734    Germany
# 27735    Germany
# 27736    Germany
# 27737    Germany
# 27738    Germany
# Name: Country, Length: 3239, dtype: object

# %%
df.loc[df["Country"] == "Germany", "Country"] = "Deutschland"

# %%
df[df["Country"] == "Deutschland"]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 24500  1743-11-01               6.326                          1.601  Berlin
# 24501  1743-12-01                 NaN                            NaN  Berlin
# 24502  1744-01-01                 NaN                            NaN  Berlin
# 24503  1744-02-01                 NaN                            NaN  Berlin
# 24504  1744-03-01                 NaN                            NaN  Berlin
# ...           ...                 ...                            ...     ...
# 27734  2013-05-01              14.139                          0.196  Berlin
# 27735  2013-06-01              17.473                          0.236  Berlin
# 27736  2013-07-01              20.901                          0.161  Berlin
# 27737  2013-08-01              19.335                          0.265  Berlin
# 27738  2013-09-01                 NaN                            NaN  Berlin
#
#            Country Latitude Longitude Planet
# ...

# %%
~pd.isna(df["AverageTemperature"]) # Tilde negiert das Ergebnis der Funktion
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 239172     True
# 239173     True
# 239174     True
# 239175     True
# 239176    False
# Name: AverageTemperature, Length: 239177, dtype: bool

# %%
df[~pd.isna(df["AverageTemperature"])] # Drop all NaN
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239171  2013-04-01              12.563                          1.823
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
#
#            City        Country Latitude Longitude Planet
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W  World
# ...

# %%
df.dropna() # easy way to drop all NaN
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239171  2013-04-01              12.563                          1.823
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
#
#            City        Country Latitude Longitude Planet
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W  World
# ...

# %% [markdown]
# # Strings bearbeiten

# %%
df["Location"] = df["City"] + ", " + df["Country"]
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude Planet                Location
# 0  Côte D'Ivoire    5.63N     3.23W  World  Abidjan, Côte D'Ivoire
# 1  Côte D'Ivoire    5.63N     3.23W  World  Abidjan, Côte D'Ivoire
# 2  Côte D'Ivoire    5.63N     3.23W  World  Abidjan, Côte D'Ivoire
# 3  Côte D'Ivoire    5.63N     3.23W  World  Abidjan, Côte D'Ivoire
# 4  Côte D'Ivoire    5.63N     3.23W  World  Abidjan, Côte D'Ivoire

# %%
#df = df.drop(["Planet"], axis=1)
df.drop(["Planet"], axis=1, inplace=True)
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude                Location
# 0  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire
# 1  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire
# 2  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire
# 3  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire
# 4  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire

# %%
df["Location"].str.split(", ").map(lambda x: x[0])
# Out:
# 0         Abidjan
# 1         Abidjan
# 2         Abidjan
# 3         Abidjan
# 4         Abidjan
#            ...
# 239172       Xian
# 239173       Xian
# 239174       Xian
# 239175       Xian
# 239176       Xian
# Name: Location, Length: 239177, dtype: object

# %%
df["Location"].str.split(", ", n=1, expand=True)
# Out:
#               0              1
# 0       Abidjan  Côte D'Ivoire
# 1       Abidjan  Côte D'Ivoire
# 2       Abidjan  Côte D'Ivoire
# 3       Abidjan  Côte D'Ivoire
# 4       Abidjan  Côte D'Ivoire
# ...         ...            ...
# 239172     Xian          China
# 239173     Xian          China
# 239174     Xian          China
# 239175     Xian          China
# 239176     Xian          China
#
# [239177 rows x 2 columns]

# %% [markdown]
# # Datentypen umwandeln

# %%
df["Longitude"]
# Out:
# 0           3.23W
# 1           3.23W
# 2           3.23W
# 3           3.23W
# 4           3.23W
#            ...
# 239172    108.97E
# 239173    108.97E
# 239174    108.97E
# 239175    108.97E
# 239176    108.97E
# Name: Longitude, Length: 239177, dtype: object

# %%
df["LongitudeDir"] = df["Longitude"].str[-1] # holt das letzte Zeichen
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude                Location LongitudeDir
# 0  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire            W
# 1  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire            W
# 2  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire            W
# 3  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire            W
# 4  Côte D'Ivoire    5.63N     3.23W  Abidjan, Côte D'Ivoire            W

# %%
df["Longitude"] = df["Longitude"].str[:-1].astype("float")
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude  Longitude                Location LongitudeDir
# 0  Côte D'Ivoire    5.63N       3.23  Abidjan, Côte D'Ivoire            W
# 1  Côte D'Ivoire    5.63N       3.23  Abidjan, Côte D'Ivoire            W
# 2  Côte D'Ivoire    5.63N       3.23  Abidjan, Côte D'Ivoire            W
# 3  Côte D'Ivoire    5.63N       3.23  Abidjan, Côte D'Ivoire            W
# 4  Côte D'Ivoire    5.63N       3.23  Abidjan, Côte D'Ivoire            W

# %%
df.loc[df["LongitudeDir"] == "W", "Longitude"] = df["Longitude"] * -1
df.drop(["LongitudeDir"], axis=1, inplace=True)

# %%
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude  Longitude                Location
# ...
