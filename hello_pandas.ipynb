# %%
import pandas as pd

# %%
df = pd.read_csv("./data/Temperature/GlobalLandTemperaturesByMajorCity.csv.bz2")
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
print(len(df))
# Out:
# 239177

# %%
df["City"]
# Out:
# 0         Abidjan
# 1         Abidjan
# 2         Abidjan
# 3         Abidjan
# 4         Abidjan
#            ...
# 239172       Xian
# 239173       Xian
# 239174       Xian
# 239175       Xian
# 239176       Xian
# Name: City, Length: 239177, dtype: object

# %%
df["City"][19002]
# Out:
# 'Bangalore'

# %%
df[["Country", "City"]].head()
# Out:
#          Country     City
# 0  Côte D'Ivoire  Abidjan
# 1  Côte D'Ivoire  Abidjan
# 2  Côte D'Ivoire  Abidjan
# 3  Côte D'Ivoire  Abidjan
# 4  Côte D'Ivoire  Abidjan

# %%
df.drop("AverageTemperatureUncertainty", axis = 1) # axis = 1 -> Spalte entfernen
# Out:
#                 dt  AverageTemperature     City        Country Latitude  \
# 0       1849-01-01              26.704  Abidjan  Côte D'Ivoire    5.63N
# 1       1849-02-01              27.434  Abidjan  Côte D'Ivoire    5.63N
# 2       1849-03-01              28.101  Abidjan  Côte D'Ivoire    5.63N
# 3       1849-04-01              26.140  Abidjan  Côte D'Ivoire    5.63N
# 4       1849-05-01              25.427  Abidjan  Côte D'Ivoire    5.63N
# ...            ...                 ...      ...            ...      ...
# 239172  2013-05-01              18.979     Xian          China   34.56N
# 239173  2013-06-01              23.522     Xian          China   34.56N
# 239174  2013-07-01              25.251     Xian          China   34.56N
# 239175  2013-08-01              24.528     Xian          China   34.56N
# 239176  2013-09-01                 NaN     Xian          China   34.56N
#
#        Longitude
# 0          3.23W
# 1          3.23W
# 2          3.23W
# 3          3.23W
# ...

# %%
df.drop("AverageTemperatureUncertainty", axis = 1, inplace = True) # axis = 1 -> Spalte entfernen, inplace = keine neue Kopie erzeugen

# %%
df
# Out:
#                 dt  AverageTemperature     City        Country Latitude  \
# 0       1849-01-01              26.704  Abidjan  Côte D'Ivoire    5.63N
# 1       1849-02-01              27.434  Abidjan  Côte D'Ivoire    5.63N
# 2       1849-03-01              28.101  Abidjan  Côte D'Ivoire    5.63N
# 3       1849-04-01              26.140  Abidjan  Côte D'Ivoire    5.63N
# 4       1849-05-01              25.427  Abidjan  Côte D'Ivoire    5.63N
# ...            ...                 ...      ...            ...      ...
# 239172  2013-05-01              18.979     Xian          China   34.56N
# 239173  2013-06-01              23.522     Xian          China   34.56N
# 239174  2013-07-01              25.251     Xian          China   34.56N
# 239175  2013-08-01              24.528     Xian          China   34.56N
# 239176  2013-09-01                 NaN     Xian          China   34.56N
#
#        Longitude
# 0          3.23W
# 1          3.23W
# 2          3.23W
# 3          3.23W
# ...
